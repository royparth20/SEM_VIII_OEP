# %%
from Display import Board
from tkinter import *

# %%
if __name__ == "__main__":
    # print(min(10,20)) 
    root = Tk()
    board = Board(root)
    root.mainloop()
# Out:
# [['', '', ''], ['', '', ''], ['o', '', '']]
# Input : [['x', '', ''], ['', '', ''], ['o', '', '']]
# Score :  0
# Depth :  0
# Movement :  False
# Score :  0
# Depth :  1
# Movement :  True
# Score :  0
# Depth :  2
# Movement :  False
# Score :  0
# Depth :  3
# Movement :  True
# Score :  0
# Depth :  4
# Movement :  False
# Score :  0
# Depth :  5
# Movement :  True
# Score :  0
# Depth :  6
# Movement :  False
# Score :  0
# Depth :  7
# Movement :  True
# Self Depth :  7 0 0
# 0 0 [['x', 'o', 'x'], ['o', 'x', 'o'], ['o', 'x', 'o']]
# ---------- BestVal : 0 ----------
# Input : [['', 'x', ''], ['', '', ''], ['o', '', '']]
# Score :  0
# Depth :  0
# Movement :  False
# Score :  0
# Depth :  1
# Movement :  True
# Score :  0
# Depth :  2
# Movement :  False
# Score :  -10
# Depth :  3
# Movement :  True
# Self Depth :  3 0 0
# Input : [['', '', 'x'], ['', '', ''], ['o', '', '']]
# Score :  0
# Depth :  0
# Movement :  False
# Score :  0
# Depth :  1
# Movement :  True
# ...
